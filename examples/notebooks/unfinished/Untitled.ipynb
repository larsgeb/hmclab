# %%
import hmc_tomography
import matplotlib.pyplot as plt

# %%
distribution = hmc_tomography.Distributions.Himmelblau(temperature=100)

# %%
sampler = hmc_tomography.Samplers.HMC.sample("samples_sn1", distribution, autotuning=True, target_acceptance_rate=0.75, proposals=100000, learning_rate=0.75, overwrite_existing_file=True)
# Out:
# sys:1: Warning:
# Silently overwriting samples file (samples_sn1.h5) if it exists.
# ...

# %%
sampler.plot_stepsizes()

# %%
sampler.plot_acceptance_rate()

# %%
with hmc_tomography.Samples("samples_sn1.h5") as samples:
    hmc_tomography.Visualization.visualize_2_dimensions(samples)
# Out:
# /home/larsgebraad/.local/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
