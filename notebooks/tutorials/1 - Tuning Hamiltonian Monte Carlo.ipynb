# %%
import hmclab
import numpy
# Out:
# /home/larsgebraad/Documents/Work/Hamiltonian Monte Carlo/hmclab/hmclab/Distributions/__init__.py:38: UserWarning: Couldn't find the required package for ElasticFullWaveform2D. Detailed errormessage: No module named '__psvWave_cpp'
#   f"Couldn't find the required package for ElasticFullWaveform2D. Detailed error"

# %% [markdown]
# # Tutorial 1 - Tuning Hamiltonian Monte Carlo

# %% [markdown]
# TODO

# %%
distribution = hmclab.Distributions.LinearMatrix.create_default(10)

# %%
sampler = hmclab.Samplers.HMC()

# %%
sampler.sample(
    "bin/02/tutorial_02.h5",
    distribution,
    autotuning=True,
    proposals=100,
    learning_rate=1.0,
    overwrite_existing_file=True,
)
# Out:
# sys:1: Warning:
# Silently overwriting samples file (bin/02/tutorial_02.h5) if it exists.
# Tot. acc rate: 0.00. Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# ...

# %%
sampler.plot_stepsizes()
# Out:
# <AxesSubplot:xlabel='iteration', ylabel='stepsize'>

# %%
sampler.sample(
    "bin/02/tutorial_02.h5",
    distribution,
    autotuning=True,
    proposals=100,
    learning_rate=0.51,
    overwrite_existing_file=True,
)
# Out:
# sys:1: Warning:
# Silently overwriting samples file (bin/02/tutorial_02.h5) if it exists.
# Tot. acc rate: 0.00. Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# ...

# %%
sampler.plot_stepsizes()
# Out:
# <AxesSubplot:xlabel='iteration', ylabel='stepsize'>
